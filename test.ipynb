# %%
import os
import pandas as pd

# %%
df = pd.read_csv('smarterbalanced_cleaned.csv', index_col=[0,1,2,3],header=[0,1])

# %%
df.head()
# Out:
#                                                                                                                        2015  \
#                                                                                              Total Number with Scored Tests
# Grade Subject Race/Ethnicity                   District
# 3     ELA     American Indian or Alaska Native Achievement First Bridgeport Academy District                            NaN
#               Black or African American        Achievement First Bridgeport Academy District                           50.0
#               Hispanic/Latino of any race      Achievement First Bridgeport Academy District                           33.0
#               White                            Achievement First Bridgeport Academy District                            NaN
#               Two or More Races                Achievement First Bridgeport Academy District                            NaN
#
# ...

# %%
df.loc[(3, 'ELA', 'Asian'),('2016')]
# Out:
# C:\Users\wengc\AppData\Local\Temp\ipykernel_28924\2009097417.py:1: PerformanceWarning: indexing past lexsort depth may impact performance.
#   df.loc[(3, 'ELA', 'Asian'),('2016')]
#                                                  Total Number with Scored Tests  \
# District
# Achievement First Bridgeport Academy District                               NaN
# Ansonia School District                                                     NaN
# Area Cooperative Educational Services                                       NaN
# Ashford School District                                                     NaN
# Avon School District                                                       40.0
# ...                                                                         ...
# Woodbridge School District                                                 13.0
# Woodstock School District                                                   NaN
# ...
